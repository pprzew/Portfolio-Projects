# %%
# Import libraries

import pandas as pd
import seaborn as sns
import numpy as np

import matplotlib
import matplotlib.pyplot as plt
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8) #Adjusts the configuration of the plots that will be created


# Read in the data

df = pd.read_csv(r'C:\Users\Piotr\Downloads\movies.csv\movies.csv')

# %%
# Let's look at the data
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7668 entries, 0 to 7667
# Data columns (total 15 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      7668 non-null   object
#  1   rating    7591 non-null   object
#  2   genre     7668 non-null   object
#  3   year      7668 non-null   int64
#  4   released  7666 non-null   object
#  5   score     7665 non-null   float64
#  6   votes     7665 non-null   float64
#  7   director  7668 non-null   object
#  8   writer    7665 non-null   object
#  9   star      7667 non-null   object
#  10  country   7665 non-null   object
#  11  budget    5497 non-null   float64
#  12  gross     7479 non-null   float64
#  13  company   7651 non-null   object
#  14  runtime   7664 non-null   float64
# dtypes: float64(5), int64(1), object(9)
# memory usage: 898.7+ KB
#                                              name rating      genre  year  \
# ...

# %%
# Let's see if there is any missing data

for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col, pct_missing))
# Out:
# name - 0.0%
# rating - 0.010041731872717789%
# genre - 0.0%
# year - 0.0%
# released - 0.0002608242044861763%
# score - 0.0003912363067292645%
# votes - 0.0003912363067292645%
# director - 0.0%
# writer - 0.0003912363067292645%
# star - 0.00013041210224308815%
# country - 0.0003912363067292645%
# budget - 0.2831246739697444%
# gross - 0.02464788732394366%
# company - 0.002217005738132499%
# runtime - 0.0005216484089723526%

# %%
# Removing all rows which have at least one missing value

df = df.dropna()

# %%
for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col, pct_missing))
# Out:
# name - 0.0%
# rating - 0.0%
# genre - 0.0%
# year - 0.0%
# released - 0.0%
# score - 0.0%
# votes - 0.0%
# director - 0.0%
# writer - 0.0%
# star - 0.0%
# country - 0.0%
# budget - 0.0%
# gross - 0.0%
# company - 0.0%
# runtime - 0.0%

# %%
# Data types for our columns

df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
# Changing the data type of the columns

df['budget'] = df['budget'].astype('int64')

df['gross'] = df['gross'].astype('int64')

df['votes'] = df['votes'].astype('int64')

df['runtime'] = df['runtime'].astype('int64')

# %%
df
# Out:
#                                                 name     rating      genre  \
# 0                                        The Shining          R      Drama
# 1                                    The Blue Lagoon          R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                          Airplane!         PG     Comedy
# 4                                         Caddyshack          R     Comedy
# ...                                              ...        ...        ...
# 7648                               Bad Boys for Life          R     Action
# 7649                              Sonic the Hedgehog         PG     Action
# 7650                                        Dolittle         PG  Adventure
# 7651                            The Call of the Wild         PG  Adventure
# 7652                               The Eight Hundred  Not Rated     Action
#
#       year                           released  score    votes  \
# ...

# %%
df['year_correct'] = df['released'].astype(str).str.partition(',')[2].str[:5]

df
# Out:
#                                                 name     rating      genre  \
# 0                                        The Shining          R      Drama
# 1                                    The Blue Lagoon          R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                          Airplane!         PG     Comedy
# 4                                         Caddyshack          R     Comedy
# ...                                              ...        ...        ...
# 7648                               Bad Boys for Life          R     Action
# 7649                              Sonic the Hedgehog         PG     Action
# 7650                                        Dolittle         PG  Adventure
# 7651                            The Call of the Wild         PG  Adventure
# 7652                               The Eight Hundred  Not Rated     Action
#
#       year                           released  score    votes  \
# ...

# %%
df = df.sort_values(by=['gross'], inplace=False, ascending=False)

# %%
#pd.set_option('display.max_rows', None)

# %%
# Drop any duplicates

#df.drop_duplicates()

# %%
df
# Out:
#                                             name     rating   genre  year  \
# 5445                                      Avatar      PG-13  Action  2009
# 7445                           Avengers: Endgame      PG-13  Action  2019
# 3045                                     Titanic      PG-13   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens      PG-13  Action  2015
# 7244                      Avengers: Infinity War      PG-13  Action  2018
# ...                                          ...        ...     ...   ...
# 5640                                 Tanner Hall          R   Drama  2009
# 2434                  Philadelphia Experiment II      PG-13  Action  1993
# 3681                                Ginger Snaps  Not Rated   Drama  2000
# 272                                     Parasite          R  Horror  1982
# 3203                                  Trojan War      PG-13  Comedy  1997
#
#                                released  score    votes             director  \
# ...

# %%
# Scatter plot with budget vs gross

plt.scatter(x=df['budget'], y=df['gross'])
plt.title('Budget vs Gross Earnings')
plt.xlabel('Budget for film')
plt.ylabel('Gross Earnings')
plt.show()

# %%
df.head()
# Out:
#                                             name rating   genre  year  \
# 5445                                      Avatar  PG-13  Action  2009
# 7445                           Avengers: Endgame  PG-13  Action  2019
# 3045                                     Titanic  PG-13   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13  Action  2015
# 7244                      Avengers: Infinity War  PG-13  Action  2018
#
#                                released  score    votes       director  \
# 5445  December 18, 2009 (United States)    7.8  1100000  James Cameron
# 7445     April 26, 2019 (United States)    8.4   903000  Anthony Russo
# 3045  December 19, 1997 (United States)    7.8  1100000  James Cameron
# 6663  December 18, 2015 (United States)    7.8   876000    J.J. Abrams
# 7244     April 27, 2018 (United States)    8.4   897000  Anthony Russo
#
#                   writer               star        country     budget  \
# ...

# %%
# Plot the budget vs gross using seaborn

sns.regplot(x='budget', y='gross', data=df, scatter_kws={"color": "red"}, line_kws={"color" : "blue"})

plt.show()

# %%
# Let's start looking at correlation

df.corr(method='pearson')
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.056386  0.206021  0.327722  0.274321  0.075077
# score    0.056386  1.000000  0.474256  0.072001  0.222556  0.414068
# votes    0.206021  0.474256  1.000000  0.439675  0.614751  0.352303
# budget   0.327722  0.072001  0.439675  1.000000  0.740247  0.318695
# gross    0.274321  0.222556  0.614751  0.740247  1.000000  0.275796
# runtime  0.075077  0.414068  0.352303  0.318695  0.275796  1.000000

# %%
# High correlaction between budget and gross

# %%
correlaction_matrix = df.corr(method='pearson')

sns.heatmap(correlaction_matrix, annot=True)
plt.title('Correlaction Matrix for Numeric Features')
plt.xlabel('Movie features')
plt.ylabel('Movie features')
plt.show()

# %%
# Looks at Company

df.head()
# Out:
#                                             name rating   genre  year  \
# 5445                                      Avatar  PG-13  Action  2009
# 7445                           Avengers: Endgame  PG-13  Action  2019
# 3045                                     Titanic  PG-13   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13  Action  2015
# 7244                      Avengers: Infinity War  PG-13  Action  2018
#
#                                released  score    votes       director  \
# 5445  December 18, 2009 (United States)    7.8  1100000  James Cameron
# 7445     April 26, 2019 (United States)    8.4   903000  Anthony Russo
# 3045  December 19, 1997 (United States)    7.8  1100000  James Cameron
# 6663  December 18, 2015 (United States)    7.8   876000    J.J. Abrams
# 7244     April 27, 2018 (United States)    8.4   897000  Anthony Russo
#
#                   writer               star        country     budget  \
# ...

# %%
df_numerized = df.copy()

for col_name in df_numerized.columns:
    if(df_numerized[col_name].dtype == 'object'):
        df_numerized[col_name] = df_numerized[col_name].astype('category')
        df_numerized[col_name] = df_numerized[col_name].cat.codes
        
df_numerized
# Out:
#       name  rating  genre  year  released  score    votes  director  writer  \
# 5445   386       5      0  2009       527    7.8  1100000       785    1263
# 7445   388       5      0  2019       137    8.4   903000       105     513
# 3045  4909       5      6  1997       534    7.8  1100000       785    1263
# 6663  3643       5      0  2015       529    7.8   876000       768    1806
# 7244   389       5      0  2018       145    8.4   897000       105     513
# ...    ...     ...    ...   ...       ...    ...      ...       ...     ...
# 5640  3794       6      6  2009       890    5.8     3500       585    2924
# 2434  2969       5      0  1993      1467    4.5     1900      1805    3102
# 3681  1595       3      6  2000      1721    6.8    43000       952    1683
# 272   2909       6      9  1982      1525    3.9     2300       261      55
# 3203  4966       5      4  1997      2152    5.7     5800       651     161
#
# ...

# %%
df
# Out:
#                                             name     rating   genre  year  \
# 5445                                      Avatar      PG-13  Action  2009
# 7445                           Avengers: Endgame      PG-13  Action  2019
# 3045                                     Titanic      PG-13   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens      PG-13  Action  2015
# 7244                      Avengers: Infinity War      PG-13  Action  2018
# ...                                          ...        ...     ...   ...
# 5640                                 Tanner Hall          R   Drama  2009
# 2434                  Philadelphia Experiment II      PG-13  Action  1993
# 3681                                Ginger Snaps  Not Rated   Drama  2000
# 272                                     Parasite          R  Horror  1982
# 3203                                  Trojan War      PG-13  Comedy  1997
#
#                                released  score    votes             director  \
# ...

# %%
correlaction_matrix = df_numerized.corr(method='pearson')

sns.heatmap(correlaction_matrix, annot=True)

plt.title('Correlaction Matrix for Numeric Features')

plt.xlabel('Movie features')

plt.ylabel('Movie features')

plt.show()

# %%
df_numerized.corr()
# Out:
#                   name    rating     genre      year  released     score  \
# name          1.000000 -0.029234  0.010996  0.025542 -0.006152  0.014450
# rating       -0.029234  1.000000  0.147796  0.019499  0.018083  0.065983
# genre         0.010996  0.147796  1.000000 -0.073167  0.022142  0.035106
# year          0.025542  0.019499 -0.073167  1.000000 -0.001740  0.056386
# released     -0.006152  0.018083  0.022142 -0.001740  1.000000  0.045874
# score         0.014450  0.065983  0.035106  0.056386  0.045874  1.000000
# votes         0.012615  0.006031 -0.135990  0.206021  0.028833  0.474256
# director      0.015246  0.014656 -0.008553 -0.038354  0.002308  0.005413
# writer        0.012880 -0.003149  0.017578 -0.025908  0.008072  0.012843
# star         -0.006882  0.009196  0.003341 -0.032157  0.015706  0.007296
# country      -0.025490  0.008230 -0.009164 -0.066748 -0.017228 -0.043051
# budget        0.023392 -0.203946 -0.368523  0.327722  0.019952  0.072001
# ...

# %%
correlaction_mat = df_numerized.corr()

corr_pairs = correlaction_mat.unstack()

corr_pairs
# Out:
# name          name            1.000000
#               rating         -0.029234
#               genre           0.010996
#               year            0.025542
#               released       -0.006152
#               score           0.014450
#               votes           0.012615
#               director        0.015246
#               writer          0.012880
#               star           -0.006882
#               country        -0.025490
#               budget          0.023392
#               gross           0.005639
#               company         0.021697
#               runtime         0.010850
#               year_correct    0.026759
# rating        name           -0.029234
#               rating          1.000000
#               genre           0.147796
#               year            0.019499
#               released        0.018083
#               score           0.065983
#               votes           0.006031
#               director        0.014656
# ...

# %%
sorted_pairs = corr_pairs.sort_values()

sorted_pairs
# Out:
# genre         budget         -0.368523
# budget        genre          -0.368523
# gross         genre          -0.244101
# genre         gross          -0.244101
# rating        budget         -0.203946
# budget        rating         -0.203946
# rating        gross          -0.181906
# gross         rating         -0.181906
# votes         genre          -0.135990
# genre         votes          -0.135990
# company       rating         -0.092357
# rating        company        -0.092357
# year          genre          -0.073167
# genre         year           -0.073167
# country       year_correct   -0.072407
# year_correct  country        -0.072407
# company       genre          -0.071334
# genre         company        -0.071334
# year_correct  genre          -0.070699
# genre         year_correct   -0.070699
# year          country        -0.066748
# country       year           -0.066748
# runtime       genre          -0.059237
# genre         runtime        -0.059237
# ...

# %%
high_corr = sorted_pairs[(sorted_pairs) > 0.5]

high_corr
# Out:
# votes         gross           0.614751
# gross         votes           0.614751
#               budget          0.740247
# budget        gross           0.740247
# year_correct  year            0.996723
# year          year_correct    0.996723
# name          name            1.000000
# company       company         1.000000
# gross         gross           1.000000
# budget        budget          1.000000
# country       country         1.000000
# star          star            1.000000
# writer        writer          1.000000
# director      director        1.000000
# votes         votes           1.000000
# score         score           1.000000
# released      released        1.000000
# year          year            1.000000
# genre         genre           1.000000
# rating        rating          1.000000
# runtime       runtime         1.000000
# year_correct  year_correct    1.000000
# dtype: float64

# %% [markdown]
# # Votes and budget have the highest correlation to gross earnings

# %%
# Let's check which companies have the highest gross earnings

df_comp = df.groupby('company').sum()
df_comp
# Out:
#                                      year  score     votes      budget  \
# company
# "DIA" Productions GmbH & Co. KG      2003   6.10  46000.00 36000000.00
# "Weathering With You" Film Partners  2019   7.50  28000.00 11100000.00
# .406 Production                      1996   6.80   5300.00   250000.00
# 1+2 Seisaku Iinkai                   2000   8.20  22000.00        0.00
# 10 West Studios                      2010   6.40   2600.00        0.00
# ...                                   ...    ...       ...         ...
# i am OTHER                           2015   7.20  82000.00  7000000.00
# i5 Films                             2001   6.60  11000.00  3000000.00
# iDeal Partners Film Fund             2013   7.50   5300.00        0.00
# micro_scope                          2010   8.30 158000.00  6800000.00
# thefyzz                              2017   5.70  51000.00  5300000.00
#
#                                            gross  runtime
# company
# ...

# %%
df_comp = df_comp.sort_values(by=['gross'], inplace=False, ascending=False)
df_comp
# Out:
#                                 year   score       votes         budget  \
# company
# Warner Bros.                  668240 2149.20 64133043.00 19568300000.00
# Universal Pictures            753986 2410.90 51082093.00 15989730001.00
# Columbia Pictures             664096 2100.10 41116704.00 15512107000.00
# Paramount Pictures            639424 2027.50 42389829.00 13723450000.00
# Twentieth Century Fox         480111 1499.90 36701007.00 11474600000.00
# ...                              ...     ...         ...            ...
# The Jerry Gross Organization    1980    4.60     3900.00      300000.00
# Abominable Pictures             2020    7.10       14.00           0.00
# The Mount Company (II)          1985    5.30      128.00           0.00
# Haruki Kadokawa Films           1990    7.00      958.00    42000000.00
# Les Films de la Tour            1985    5.60      139.00           0.00
#
#                                       gross  runtime
# company
# ...

# %%
df_comp = df_comp[['budget', 'gross']]

# %%
pd.set_option('display.float_format', lambda x: '%.0f' % x)

# %%
df_comp
# Out:
#                                   budget       gross
# company
# Warner Bros.                 19568300000 56491421806
# Universal Pictures           15989730001 52514188890
# Columbia Pictures            15512107000 43008941346
# Paramount Pictures           13723450000 40493607415
# Twentieth Century Fox        11474600000 40257053857
# ...                                  ...         ...
# The Jerry Gross Organization      300000           0
# Abominable Pictures                    0           0
# The Mount Company (II)                 0           0
# Haruki Kadokawa Films           42000000           0
# Les Films de la Tour                   0           0
#
# [2385 rows x 2 columns]

# %%
df_comp20 = df_comp[:20]

# %%
df_comp20
# Out:
#                                    budget       gross
# company
# Warner Bros.                  19568300000 56491421806
# Universal Pictures            15989730001 52514188890
# Columbia Pictures             15512107000 43008941346
# Paramount Pictures            13723450000 40493607415
# Twentieth Century Fox         11474600000 40257053857
# Walt Disney Pictures          10404700000 36327887792
# New Line Cinema                5648200000 19883797684
# Marvel Studios                 2664000000 15065592411
# DreamWorks Animation           3344000000 11873612858
# Touchstone Pictures            4153700000 11795832638
# Dreamworks Pictures            3961700000 11635441081
# Metro-Goldwyn-Mayer (MGM)      3548250000  9230230105
# Summit Entertainment           2655269000  8373718838
# Pixar Animation Studios        1756000000  7886344526
# Fox 2000 Pictures              2329500000  7443502667
# Lucasfilm                      1149000000  7185352192
# ...

# %%
plt.bar(x=df_comp20.index, height=df_comp20['gross'])
plt.xlabel('Company')
plt.ylabel('Gross Earnings')
plt.gcf().autofmt_xdate()
plt.show()
